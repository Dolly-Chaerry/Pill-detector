# %%
import numpy as np

# %%
data = np.load("../features.npz")

print("Keys inside the file:", list(data.keys()))
# Out:
# Keys inside the file: ['features', 'labels']

# %%
X = data['features']
y = data['labels']

# %%
print(X.shape)
print(y.shape)
# Out:
# (1316, 43)
# (1316,)
